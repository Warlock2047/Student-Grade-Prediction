# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
sns.set_style('darkgrid')

# %%
df = pd.read_csv("student-mat.csv")
pd.get_option("display.max_rows",500)
pd.get_option("display.max_columns",50)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %%
px.imshow(df.corr())

# %%
sns.countplot(df["school"])
# Out:
# <AxesSubplot:xlabel='school', ylabel='count'>

# %%
sns.countplot(df["sex"])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.displot(x="age",data=df)
# Out:
# NumExpr defaulting to 8 threads.

# %%
sns.countplot(df["address"])
# Out:
# <AxesSubplot:xlabel='address', ylabel='count'>

# %%
sns.countplot(df["famsize"])
# Out:
# <AxesSubplot:xlabel='famsize', ylabel='count'>

# %%
sns.countplot(df["Pstatus"],hue=df["famsize"])
# Out:
# <AxesSubplot:xlabel='Pstatus', ylabel='count'>

# %%
sns.countplot(df["Pstatus"],hue=df["address"])
# Out:
# <AxesSubplot:xlabel='Pstatus', ylabel='count'>

# %%
sns.countplot(df["Pstatus"],hue=df["sex"])
# Out:
# <AxesSubplot:xlabel='Pstatus', ylabel='count'>

# %%
sns.countplot(df["Medu"])
# Out:
# <AxesSubplot:xlabel='Medu', ylabel='count'>

# %%
sns.countplot(df["Medu"],hue=df["Pstatus"])
# Out:
# <AxesSubplot:xlabel='Medu', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.countplot(x="Fedu",data=df)
plt.subplot(2,2,2)
sns.countplot(x="Medu",data=df)
# Out:
# <AxesSubplot:xlabel='Medu', ylabel='count'>

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.countplot(x="Mjob",data=df)
plt.xlabel('Mother Job')
plt.subplot(2,2,2)
sns.countplot(x="Fjob",data=df)
plt.xlabel('Father Job')
# Out:
# Text(0.5, 0, 'Father Job')

# %%
sns.countplot(x='reason',hue='school',data=df)
# Out:
# <AxesSubplot:xlabel='reason', ylabel='count'>

# %%
sns.countplot(x='guardian',data=df)
# Out:
# <AxesSubplot:xlabel='guardian', ylabel='count'>

# %%
sns.countplot(x='traveltime',data=df)
# Out:
# <AxesSubplot:xlabel='traveltime', ylabel='count'>

# %%
df['G1_G2_G3'] = (df['G1'] +df['G2']+df['G3'] )/3
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3   G1_G2_G3
# 0        3     4     1     1       3        6   5   6   6   5.666667
# 1        3     3     1     1       3        4   5   5   6   5.333333
# 2        3     2     2     3       3       10   7   8  10   8.333333
# 3        2     2     1     1       5        2  15  14  15  14.666667
# 4        3     2     1     2       5        4   6  10  10   8.666667
#
# [5 rows x 34 columns]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x ='school',y='G1_G2_G3',hue='sex',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='school', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ='school',y='G1_G2_G3',hue='sex',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='school', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x ='age',y='G1_G2_G3',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(x ='age',hue='sex',data=df,shade=4)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x ='address',y='G1_G2_G3',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='address', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ='address',y='G1_G2_G3',hue='sex',data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='address', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ='famsize',y='G1_G2_G3',hue='sex',data=df,palette='mako')
# Out:
# <AxesSubplot:xlabel='famsize', ylabel='G1_G2_G3'>

# %%
fig = sns.FacetGrid(df,hue="sex",aspect=4,palette="mako")
fig.map(sns.kdeplot,"G1_G2_G3",shade=True)
high = df["G1_G2_G3"].max()
fig.set(xlim=(0,high))
fig.add_legend()

# %%
fig = sns.FacetGrid(df,hue="school",aspect=4,palette="viridis")
fig.map(sns.kdeplot,"G1_G2_G3",shade=True)
high = df["G1_G2_G3"].max()
fig.set(xlim=(0,high))
fig.add_legend()

# %%
fig = sns.FacetGrid(df,hue="guardian",aspect=4,palette="flare")
fig.map(sns.kdeplot,"G1_G2_G3",shade=True)
high = df["G1_G2_G3"].max()
fig.set(xlim=(0,high))
fig.add_legend()

# %%
fig = sns.FacetGrid(df,hue="traveltime",aspect=4,palette="mako")
fig.map(sns.kdeplot,"G1_G2_G3",shade=True)
high = df["G1_G2_G3"].max()
fig.set(xlim=(0,high))
fig.add_legend()

# %%
sns.scatterplot(x='traveltime',y='G1_G2_G3',hue='address',data=df)
# Out:
# <AxesSubplot:xlabel='traveltime', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='studytime',data=df)
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x ='studytime',y='G1_G2_G3',hue='sex',data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x ='studytime',y='G1_G2_G3',hue='sex',data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(x ='studytime',y='G1_G2_G3',hue='sex',data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='studytime', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['failures'])
# Out:
# <AxesSubplot:xlabel='failures', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['failures'],hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='failures', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['failures'],y=df['G1_G2_G3'],hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='failures', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['schoolsup'])
print('Schoolsup Yes',len(df['schoolsup'].loc[df['schoolsup']=='yes']))
print('Schoolsup No',len(df['schoolsup'].loc[df['schoolsup']=='no']))
# Out:
# Schoolsup Yes 51
# Schoolsup No 344

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['schoolsup'],y=df['G1_G2_G3'],hue=df['Pstatus'])
# Out:
# <AxesSubplot:xlabel='schoolsup', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df["famsup"])
# Out:
# <AxesSubplot:xlabel='famsup', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(df["G1_G2_G3"],hue=df["famsup"],shade=True)
# Out:
# <AxesSubplot:xlabel='G1_G2_G3', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(df["G1_G2_G3"],hue=df["schoolsup"],shade=True)
# Out:
# <AxesSubplot:xlabel='G1_G2_G3', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df["paid"])
# Out:
# <AxesSubplot:xlabel='paid', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(df["G1_G2_G3"],hue=df["paid"],shade=True)
# Out:
# <AxesSubplot:xlabel='G1_G2_G3', ylabel='Density'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y=df["G1_G2_G3"],x=df["paid"])
# Out:
# <AxesSubplot:xlabel='paid', ylabel='G1_G2_G3'>

# %%
plt.figure(figsize=(12,6))
sns.countplot(df["activities"])
# Out:
# <AxesSubplot:xlabel='activities', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.kdeplot(df["G1_G2_G3"],hue=df["activities"],shade=4)
plt.subplot(2,2,2)
sns.kdeplot(df["G1"],hue=df["activities"],shade=4)
plt.subplot(2,2,3)
sns.kdeplot(df["G2"],hue=df["activities"],shade=4)
plt.subplot(2,2,4)
sns.kdeplot(df["G3"],hue=df["activities"],shade=4)
# Out:
# <AxesSubplot:xlabel='G3', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.boxplot(y=df["G1_G2_G3"],x=df["activities"])
plt.subplot(2,2,2)
sns.boxplot(y=df["G1"],x=df["activities"])
plt.subplot(2,2,3)
sns.boxplot(y=df["G2"],x=df["activities"])
plt.subplot(2,2,4)
sns.boxplot(y=df["G3"],x=df["activities"])
# Out:
# <AxesSubplot:xlabel='activities', ylabel='G3'>
